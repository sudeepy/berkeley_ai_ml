# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.tsa.arima_process as arima_process

# %% [markdown]
# # Create a process and take a sample

# %%
process = arima_process.ArmaProcess(ar=[1, -0.8], ma=[1])

# %%
process
# Out:
# ArmaProcess([1.0, -0.8], [1.0], nobs=100) at 0x15401cd90

# %%
z = process.generate_sample(nsample=100)
z
# Out:
# array([-0.40788303,  0.2822431 ,  0.48889254,  1.25489876,  1.85169391,
#         2.60692914,  0.83065611, -0.24919076, -1.51173742, -1.181827  ,
#         1.03572254,  0.60621624, -0.57600399, -1.22826954, -0.61720522,
#        -1.12413026, -0.99481063, -2.89756709, -2.27178692, -2.28465642,
#        -2.91555795, -2.95935307, -2.19152227, -3.41118279, -2.58456564,
#        -1.3232476 , -2.07768329, -2.24964269, -1.62766584, -2.03662538,
#        -2.09232425,  0.59482306,  1.48096628,  0.45363938,  0.61172704,
#         0.11443519,  0.65131222,  1.39351491,  2.16990195,  0.03726318,
#         0.11084494,  0.23679793,  0.73308571,  1.44979653,  0.05194217,
#        -0.0441032 , -0.81999425,  0.26403613, -0.9210971 , -2.09107993,
#        -1.36068478,  0.47851174,  0.9986685 , -0.97905991, -1.20990411,
#        -0.6908052 ,  1.30722629,  3.42823368,  2.97555117,  3.16025927,
#         1.38640907,  1.39896691,  1.65133236, -0.03145056, -0.26074687,
#        -0.70297874,  0.43702231, -0.65280503, -0.74574855, -1.90817875,
#        -1.72872723, -0.6747883 , -0.16024565, -1.15461951, -0.7135856 ,
#        -0.47261324, -2.35267132, -2.68856761, -2.81730867, -0.27622025,
#        -0.48752493, -0.93153346, -0.58257833, -1.94484831, -0.97637808,
#        -1.03972643, -1.19783845, -0.58875793, -1.27819651, -0.98151381,
#        -0.28054164,  0.35849388, -0.00672246, -0.20952338, -0.84023217,
#        -1.58259544, -1.97738371, -1.04540936, -1.28690416, -0.38681735])

# %%
plt.figure(figsize=(10, 5))
plt.plot(z, linewidth=2, marker='.')

# %% [markdown]
# # Compute autocorrelations

# %%
acf = process.acf(lags=20)
acf
# Out:
# array([1.        , 0.8       , 0.64      , 0.512     , 0.4096    ,
#        0.32768   , 0.262144  , 0.2097152 , 0.16777216, 0.13421773,
#        0.10737418, 0.08589935, 0.06871948, 0.05497558, 0.04398047,
#        0.03518437, 0.0281475 , 0.022518  , 0.0180144 , 0.01441152])

# %%
plt.figure(figsize=(10, 4))
plt.stem(acf)
plt.xticks(ticks=range(0, 20, 2))
plt.show()

# %% [markdown]
# # Plotting sample autocorrelations

# %%
import statsmodels.graphics.tsaplots as tsaplots

# %%
fig, ax = plt.subplots(figsize=(10, 4))
tsaplots.plot_acf(z, lags=20, ax=ax)
plt.show()

# %% [markdown]
# # Sunspots data

# %%
sunspots = pd.read_csv('
